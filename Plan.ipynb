# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import car_data
import pic

while True:
    
    print("")
    print("☆★☆☆★☆~~~歡迎來到Justin車廠~~~☆★☆☆★☆   ◢███◣。。。。。。◢███◣")
    print("☆★☆☆★☆★☆祝大家周末母親節快樂☆★☆☆★☆     ▇▇□██。。。。。。██□██")
    print("☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆      ◥███◤◢████◣◥███◤")
    print("★☆★☆☆★☆祝大家周末母親節快樂☆★☆☆★☆      ◢█。。。。。。。。。。。。█◣")
    print("☆★☆★☆★☆★☆★☆★☆★☆★☆★☆★☆☆★☆☆★☆☆★   █。╔╗。。。。。。。。╔╗。█")
    print("                                               █。∥●。。。╭╮。。。∥●。█              ")
    print("                                               █。╚╝。。。╰╯。。。╚╝。█            ")
    print("                                               ◥▆▆▆▆▆▆▆▆▆▆▆▆▆▆◤           ")
    print("                                                  祝大家周末母親節快樂            ")


    print("1.新增車輛款式:")
    print("2.查詢你想購買的車子:")
    print("3.刪除車輛")
    print("4.上個月銷售圖表")
    print("5.或按數字5退出")
    
    Ans =eval(input("請輸入你要執行的功能"))

    if Ans == 1:
        car_data.car_name()
    elif Ans == 2:
        car_data.search()
    elif Ans == 3:
        car_data.del_car()
    elif Ans == 4:
        pic.pic()
    else:
        print("")
        print("     謝謝你來賞車，歡迎再度光臨")
        print("     謝謝你來賞車，歡迎再度光臨")
        print("")
        print("     █████████  █         █       ██       ██      █  █    ██   ")
        print("         █      █         █      ████      █ █     █  █   ██    ")
        print("         █      █         █     ██  ██     █  █    █  █  ██     ")
        print("         █      ███████████    ██    ██    █   █   █  ████      ")
        print("         █      █         █   ██████████   █    █  █  █  ██     ")
        print("         █      █         █  ██        ██  █     █ █  █   ██    ")
        print("         █      █         █ ██          ██ █      ██  █    ██   ")
        
        break
# Out:
# ☆★☆☆★☆~~~歡迎來到Justin車廠~~~☆★☆☆★☆   ◢███◣。。。。。。◢███◣
# ☆★☆☆★☆★☆祝大家周末母親節快樂☆★☆☆★☆     ▇▇□██。。。。。。██□██
# ☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆      ◥███◤◢████◣◥███◤
# ★☆★☆☆★☆祝大家周末母親節快樂☆★☆☆★☆      ◢█。。。。。。。。。。。。█◣
# ☆★☆★☆★☆★☆★☆★☆★☆★☆★☆★☆☆★☆☆★☆☆★   █。╔╗。。。。。。。。╔╗。█
#                                                █。∥●。。。╭╮。。。∥●。█
#                                                █。╚╝。。。╰╯。。。╚╝。█
#                                                ◥▆▆▆▆▆▆▆▆▆▆▆▆▆▆◤
#                                                   祝大家周末母親節快樂
# 1.新增車輛款式:
# 2.查詢你想購買的車子:
# 3.刪除車輛
# 4.上個月銷售圖表
# 5.或按數字5退出
# 請輸入你要執行的功能2
#
#
# ▼▼▼▼▼▼以下列表是本廠目前有販售的車輛▼▼▼▼▼▼
#                 car  year  door   color    cc  price(10K)
# 0   Ferrari 812 GTS  2020     2   black  6496        1980
# 1  Maserrati Ghibli  2020     4   black  2979         570
# 2  Porsche Panamera  2020     2    gray  2995        1000
# 3             Tesla  2020     4   white     0         300
# 4            BMW X6  2020     4   black  2998         560
# 5      BENZ A Class  2020     4  yellow  2000         300
# 6              CR-V  2020     4     red  2400         120
# 7              HR-V  2020     4    blue  2000          80
# 8             Yaris  2020     4    gray  2000          60
# 9             Tiida  2020     4     red  2000          60
#
# ☆★☆☆★☆~~~歡迎來到Justin車廠~~~☆★☆☆★☆   ◢███◣。。。。。。◢███◣
# ☆★☆☆★☆★☆祝大家周末母親節快樂☆★☆☆★☆     ▇▇□██。。。。。。██□██
# ☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆      ◥███◤◢████◣◥███◤
# ★☆★☆☆★☆祝大家周末母親節快樂☆★☆☆★☆      ◢█。。。。。。。。。。。。█◣
# ☆★☆★☆★☆★☆★☆★☆★☆★☆★☆★☆☆★☆☆★☆☆★   █。╔╗。。。。。。。。╔╗。█
#                                                █。∥●。。。╭╮。。。∥●。█
#                                                █。╚╝。。。╰╯。。。╚╝。█
#                                                ◥▆▆▆▆▆▆▆▆▆▆▆▆▆▆◤
#                                                   祝大家周末母親節快樂
# 1.新增車輛款式:
# 2.查詢你想購買的車子:
# 3.刪除車輛
# 4.上個月銷售圖表
# 5.或按數字5退出
# 請輸入你要執行的功能4
# ☆★☆☆★☆~~~歡迎來到Justin車廠~~~☆★☆☆★☆   ◢███◣。。。。。。◢███◣
# ☆★☆☆★☆★☆祝大家周末母親節快樂☆★☆☆★☆     ▇▇□██。。。。。。██□██
# ☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆☆★☆      ◥███◤◢████◣◥███◤
# ★☆★☆☆★☆祝大家周末母親節快樂☆★☆☆★☆      ◢█。。。。。。。。。。。。█◣
# ☆★☆★☆★☆★☆★☆★☆★☆★☆★☆★☆☆★☆☆★☆☆★   █。╔╗。。。。。。。。╔╗。█
#                                                █。∥●。。。╭╮。。。∥●。█
#                                                █。╚╝。。。╰╯。。。╚╝。█
#                                                ◥▆▆▆▆▆▆▆▆▆▆▆▆▆▆◤
#                                                   祝大家周末母親節快樂
# 1.新增車輛款式:
# 2.查詢你想購買的車子:
# 3.刪除車輛
# 4.上個月銷售圖表
# 5.或按數字5退出
# 請輸入你要執行的功能5
#
#      謝謝你來賞車，歡迎再度光臨
#      謝謝你來賞車，歡迎再度光臨
#
#      █████████  █         █       ██       ██      █  █    ██
#          █      █         █      ████      █ █     █  █   ██
#          █      █         █     ██  ██     █  █    █  █  ██
#          █      ███████████    ██    ██    █   █   █  ████
#          █      █         █   ██████████   █    █  █  █  ██
#          █      █         █  ██        ██  █     █ █  █   ██
#          █      █         █ ██          ██ █      ██  █    ██

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

def pic():#圖表

    x = [70,80,90,100,110,120,130,140,150]
    y = [1980,570,1000,300,560,300,120,80,60]

    t1 = ["Ferrari","Maserrati","Porsche","Tesla","BMW","BENZ",
         "CR-V","HR-V","Yaris"]

    plt.figure(figsize = (8,4))

    plt.bar(x, y,width = 5,tick_label=t1, label = "d")
    plt.legend()
    plt.xlabel("Car")
    plt.ylabel("price  (10K)")
    plt.title("Car yesterday price menu")

    #(\/)@.@(\/)
    plt.show()
